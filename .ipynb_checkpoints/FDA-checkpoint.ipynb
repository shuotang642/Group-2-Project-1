# %%
# Dependencies
import requests
import json
import pandas as pd

from datetime import datetime
from dateutil.parser import parse

# %% [markdown]
# https://open.fda.gov/apis/food/enforcement/

# %%
# Performing a GET Request and saving the 
# API's response within a variable

with open('food.json') as json_file:
    data = json.load(json_file)


#Importing to dataframe

TotalRecall = pd.DataFrame(data['results'])

group = TotalRecall.groupby(['state'])

count = group.count()

TotalRecall
# Out:
#            classification center_classification_date report_date postal_code  \
# 0                Class II                   20120926    20121003  90021-1616
# 1                 Class I                   20120924    20121003  91706-2161
# 2                Class II                   20120927    20121003  92833-2510
# 3                Class II                   20120927    20121003  92833-2510
# 4                Class II                   20120921    20121003  17545-9639
# ...                   ...                        ...         ...         ...
# 18910  Not Yet Classified                        NaN    20191127  56482-1205
# 18911            Class II                   20160203    20160210  94568-2907
# 18912             Class I                   20160202    20160210  32254-3601
# 18913            Class II                   20160203    20160210       02150
# 18914            Class II                   20160129    20160210  90012-1812
#
#       termination_date recall_initiation_date recall_number          city  \
# 0             20120926               20120921   F-2396-2012   Los Angeles
# 1             20121025               20120831   F-2382-2012     Irwindale
# 2             20121217               20120712   F-2438-2012     Fullerton
# 3             20121217               20120712   F-2436-2012     Fullerton
# 4             20130716               20120417   F-2374-2012       Manheim
# ...                ...                    ...           ...           ...
# 18910              NaN               20191105                      Wadena
# 18911         20170321               20151205   F-0535-2016        Dublin
# 18912         20170330               20151028   F-0531-2016  Jacksonville
# 18913              NaN               20151220   F-0523-2016       Chelsea
# 18914         20161014               20160107   F-0526-2016   Los Angeles
#
#       more_code_info event_id  ...  \
# 0               None    63150  ...
# 1               None    63062  ...
# 2               None    62991  ...
# 3               None    62991  ...
# 4               None    62465  ...
# ...              ...      ...  ...
# 18910            NaN    84222  ...
# 18911           None    72858  ...
# 18912           None    72664  ...
# 18913           None    72905  ...
# 18914           None    73019  ...
#
#                                        reason_for_recall  \
# 0      M & K Trading is recalling Korean Molluscan Sh...
# 1      Firm is voluntarily recalling, out of an abund...
# 2      The firm recalled due to a potential non-safet...
# 3      The firm recalled due to a potential non-safet...
# 4      FDA samples of product tested positive for Fum...
# ...                                                  ...
# 18910  Products are being recalled because they may h...
# 18911  The product may not have been transported at a...
# 18912                                 Undeclared walnuts
# 18913               Product may contain metal fragments.
# 18914  Madison One Acme, Inc. dba Solstice Medicine i...
#
#                                initial_firm_notification      status  \
# 0                                                 E-Mail  Terminated
# 1                                          Press Release  Terminated
# 2                                                 Letter  Terminated
# 3                                                 Letter  Terminated
# 4                                              Telephone  Terminated
# ...                                                  ...         ...
# 18910  Two or more of the following: Email, Fax, Lett...     Ongoing
# 18911                                          Telephone  Terminated
# 18912  Two or more of the following: Email, Fax, Lett...  Terminated
# 18913                                             E-Mail     Ongoing
# 18914                                          Telephone  Terminated
#
#       product_type        country  \
# 0             Food  United States
# 1             Food  United States
# 2             Food  United States
# 3             Food  United States
# 4             Food  United States
# ...            ...            ...
# 18910         Food  United States
# 18911         Food  United States
# 18912         Food  United States
# 18913         Food  United States
# 18914         Food  United States
#
#                                      product_description  \
# 0                              Seasoned Clams, 240 grams
# 1      Ready Pac¿ Sliced Mango, 10.5oz , UPC 77745237...
# 2      Wildwood Organic Mild Salsa , 14 oz, Pack size...
# 3      Wildwood Emerald Valley Kitchen Organic Medium...
# 4      Bulk Foods, Inc. Yellow Corn Meal, Regular Roa...
# ...                                                  ...
# 18910  Veggie Blend with Dill Dip, 12 oz, in plastic ...
# 18911  Dockside Classics  4 Premium  Crab Cakes  Net ...
# 18912  Cookie Platter Containing Oatmeal Rasin Cookie...
# 18913  Signature Breads Frozen Parbaked French Sub Gr...
# 18914  Tong Ren Tang  Shenjing Shuairuo Wan  Herbal S...
#
#                                                code_info  \
# 0                                         not available.
# 1      UPC 7774523746, Use by dates 9/8/2012 or earli...
# 2                   UPC 0-30871-33001-2, Item # 0291710.
# 3                   UPC 0-52334-11659-9, Item # 0291661.
# 4      No codes; all product "Purchase by date shown ...
# ...                                                  ...
# 18910     UPC 795631827149, Sell by 10/10/19 to 11/10/19
# 18911                                  UPC: 045425165446
# 18912  48-count - UPC 00269736000009, SLU 69736;     ...
# 18913                             Use by Date: 9/17/2016
# 18914                      SMC Code: TRT10  Lot #2080130
#
#                     address_1 address_2  \
# 0            748 S Alameda St
# 1             4401 Foxdale St
# 2              2315 Moore Ave
# 3              2315 Moore Ave
# 4      1720 Locust Grove Road
# ...                       ...       ...
# 18910           266 4th St NE
# 18911     6511 Golden Gate Dr
# 18912        5050 Edgewood Ct
# 18913        100 Justin Drive
# 18914            215 W Ann St
#
#                                 product_quantity
# 0                                       39 units
# 1                                     1544 cases
# 2                                      602 units
# 3                                      575 units
# 4
# ...                                          ...
# 18910                                 4507 units
# 18911                                   20 cases
# 18912  21,600 total Baked Oatmeal Raisin Cookies
# 18913                          1,893 cases Total
# 18914                                      12500
#
# [18915 rows x 25 columns]

# %% [markdown]
# Analysis Goals:
#
# 1.  Calculate Recall Durations and compare to notification method, and year
#
# 2.  **Ambitious** Find keywords in product description as another grouping method
#
# 3.  Group by states and see track recall frequency changes over time
#
# 4.

# %%
TotalRecall['recall duration'] = pd.to_datetime(TotalRecall['recall_initiation_date'],format= '%Y%m%d', errors='ignore').values - pd.to_datetime(TotalRecall['termination_date'],format= '%Y%m%d', errors='ignore').values


TotalRecall
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-ff10315e6a4f> in <module>
# ----> 1 TotalRecall['recall duration'] = pd.to_datetime(TotalRecall['recall_initiation_date'],format= '%Y%m%d', errors='ignore').values - pd.to_datetime(TotalRecall['termination_date'],format= '%Y%m%d', errors='ignore').values
#       2
#       3
#       4 TotalRecall
#
# TypeError: ufunc subtract cannot use operands with types dtype('O') and dtype('<M8[ns]')
