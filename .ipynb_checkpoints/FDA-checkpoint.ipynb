# %%
# Dependencies
import requests
import json

# %%
# Performing a GET Request and saving the 
# API's response within a variable

with open('food.json') as json_file:
    data = json.load(json_file)


data['results'][1:10]
# Out:
# [{'classification': 'Class I',
#   'center_classification_date': '20120924',
#   'report_date': '20121003',
#   'postal_code': '91706-2161',
#   'termination_date': '20121025',
#   'recall_initiation_date': '20120831',
#   'recall_number': 'F-2382-2012',
#   'city': 'Irwindale',
#   'more_code_info': None,
#   'event_id': '63062',
#   'distribution_pattern': 'Nationwide to following US States and Canada: Alaska, Alabama, Arkansas, Arizona, California, Colorado, Connecticut, Delaware,  District of Columbia, Washington D.C., Florida, Georgia, Hawaii, Iowa, Idaho, Illinois, Indiana, Kentucky,  Louisiana, Massachusetts, Maryland, Michigan, Minnesota, Missouri, Mississippi, Montana, Nebraska,  Nevada, New Hampshire, New Jersey, New Mexico, New York, North Carolina, North Dakota, Ohio,  Oklahoma, Oregon, Pennsylvania, Rhode Island, South Carolina, South Dakota, Tennessee, Texas, Utah,  Virginia, Vermont, Washington, Wisconsin, Wyoming, and Canada.',
#   'openfda': {},
#   'recalling_firm': 'Ready Pac Foods Inc',
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'state': 'CA',
#   'reason_for_recall': 'Firm is voluntarily recalling, out of an abundance of caution, packaged fruit products containing mangoes, distributed through August 30th 2012, since they contain Daniella Brand mandoes, which have been recalled by supplier Splendid Products, due to potential contamination with Salmonella Braenderup.',
#   'initial_firm_notification': 'Press Release',
#   'status': 'Terminated',
#   'product_type': 'Food',
#   'country': 'United States',
#   'product_description': 'Ready Pac¿ Sliced Mango, 10.5oz , UPC 7774523751, Use by dates 9/8/2012 or earlier, 9/6/2012 & 9/7/2012.  Ready Pac¿ Sliced Mango, 32oz, UPC 0000088356, Use by dates 9/6/2012 & 9/7/2012. Ready Pac¿ Sliced Mango, 32 oz, UPC 7774522859, Use by dates 9/8/2012 or earlier and 9/6/2012 & 9/7/2012.',
#   'code_info': 'UPC 7774523746, Use by dates 9/8/2012 or earlier, 9/6/2012 & 9/7/2012.  UPC 7774524023, Use by dates 9/8/2012 or earlier and 9/8/2012.',
#   'address_1': '4401 Foxdale St',
#   'address_2': '',
#   'product_quantity': '1544 cases'},
#  {'classification': 'Class II',
#   'center_classification_date': '20120927',
#   'report_date': '20121003',
#   'postal_code': '92833-2510',
#   'termination_date': '20121217',
#   'recall_initiation_date': '20120712',
#   'recall_number': 'F-2438-2012',
#   'city': 'Fullerton',
#   'more_code_info': None,
#   'event_id': '62991',
#   'distribution_pattern': 'Nationwide and Canada.',
#   'openfda': {},
#   'recalling_firm': 'Pulmuone Wildwood Inc',
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'state': 'CA',
#   'reason_for_recall': 'The firm recalled due to a potential non-safety quality concern related to a particular ingredient that was causing premature spoilage.',
#   'initial_firm_notification': 'Letter',
#   'status': 'Terminated',
#   'product_type': 'Food',
#   'country': 'United States',
#   'product_description': 'Wildwood Organic Mild Salsa , 14 oz, Pack size 6/14 oz per case. Packaged in plastic cup, sealed with film and capped with plastic cap. Product labeling reads in part:" WILDWOOD ORGANIC salsa MILD ***NET WT. 14OZ, MANUFACTURED BY PULMUONE FOODS USA, Inc. Fullerton, CA 92833***".',
#   'code_info': 'UPC 0-30871-33001-2, Item # 0291710.',
#   'address_1': '2315 Moore Ave',
#   'address_2': '',
#   'product_quantity': '602 units'},
#  {'classification': 'Class II',
#   'center_classification_date': '20120927',
#   'report_date': '20121003',
#   'postal_code': '92833-2510',
#   'termination_date': '20121217',
#   'recall_initiation_date': '20120712',
#   'recall_number': 'F-2436-2012',
#   'city': 'Fullerton',
#   'more_code_info': None,
#   'event_id': '62991',
#   'distribution_pattern': 'Nationwide and Canada.',
#   'openfda': {},
#   'recalling_firm': 'Pulmuone Wildwood Inc',
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'state': 'CA',
#   'reason_for_recall': 'The firm recalled due to a potential non-safety quality concern related to a particular ingredient that was causing premature spoilage.',
#   'initial_firm_notification': 'Letter',
#   'status': 'Terminated',
#   'product_type': 'Food',
#   'country': 'United States',
#   'product_description': 'Wildwood Emerald Valley Kitchen Organic Medium Salsa - Canada (containing French in labeling), 397 mL. Pack size 6/14 oz per case. Packaged in plastic cup, sealed with film and capped with plastic cap. Product labeling reads in part:" WILDWOOD Emerald Valley KITCHEN ORGANIC MEDIUM SALSA***NET WT. 397mL, MANUFACTURED BY PULMUONE FOODS USA, Inc. Fullerton, CA 92833***".',
#   'code_info': 'UPC 0-52334-11659-9, Item # 0291661.',
#   'address_1': '2315 Moore Ave',
#   'address_2': '',
#   'product_quantity': '575 units'},
#  {'classification': 'Class II',
#   'center_classification_date': '20120921',
#   'report_date': '20121003',
#   'postal_code': '17545-9639',
#   'termination_date': '20130716',
#   'recall_initiation_date': '20120417',
#   'recall_number': 'F-2374-2012',
#   'city': 'Manheim',
#   'more_code_info': None,
#   'event_id': '62465',
#   'distribution_pattern': 'Product was distributed to specific wholesale and retail outlets within the State of Pennsylvania',
#   'openfda': {},
#   'recalling_firm': 'Haldeman Mills',
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'state': 'PA',
#   'reason_for_recall': 'FDA samples of product tested positive for Fumonisin',
#   'initial_firm_notification': 'Telephone',
#   'status': 'Terminated',
#   'product_type': 'Food',
#   'country': 'United States',
#   'product_description': 'Bulk Foods, Inc. Yellow Corn Meal, Regular Roast, 25 lb; Bulk Foods, Inc. Yellow Corn Meal, Regular Roast, 50 lb',
#   'code_info': 'No codes; all product "Purchase by date shown 12/29/2012"',
#   'address_1': '1720 Locust Grove Road',
#   'address_2': '',
#   'product_quantity': ''},
#  {'classification': 'Class I',
#   'center_classification_date': '20120921',
#   'report_date': '20121003',
#   'postal_code': '92056-5856',
#   'termination_date': '20121119',
#   'recall_initiation_date': '20120824',
#   'recall_number': 'F-2368-2012',
#   'city': 'Oceanside',
#   'more_code_info': None,
#   'event_id': '63002',
#   'distribution_pattern': 'nationwide in the US and worldwide to Canada and United Kingdom.',
#   'openfda': {},
#   'recalling_firm': 'MyoSci Technologies Inc.',
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'state': 'CA',
#   'reason_for_recall': 'True Nutrition is recalling Whey Protein Isolate, Whey Protein Concentrate, and Hydrolyzed Whey Protein because they contain undeclared milk.',
#   'initial_firm_notification': 'Press Release',
#   'status': 'Terminated',
#   'product_type': 'Food',
#   'country': 'United States',
#   'product_description': 'Whey Protein Isolate Cold-Filtration, Net Weight: 1lb (454g)',
#   'code_info': 'Batch/Lot#0030812',
#   'address_1': '3919 Oceanic Dr Ste 703',
#   'address_2': '',
#   'product_quantity': '200 units'},
#  {'classification': 'Class I',
#   'center_classification_date': '20120924',
#   'report_date': '20121003',
#   'postal_code': '49548-5639',
#   'termination_date': '20121204',
#   'recall_initiation_date': '20120830',
#   'recall_number': 'F-2390-2012',
#   'city': 'Wyoming',
#   'more_code_info': None,
#   'event_id': '63058',
#   'distribution_pattern': 'restaurants and GFS retail outlets in Florida',
#   'openfda': {},
#   'recalling_firm': 'Gordon Food Service',
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'state': 'MI',
#   'reason_for_recall': 'Gordon Food Service is recalling Tropical Food Nut & Fruit Shelled Raw Pistachios , because there is potential for the box to be mis-packed with chopped peanuts.  People who have an allergy or severe sensitivity to peanuts run the risk of serious or life-threatening allergic reaction if they consume this product.',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'status': 'Terminated',
#   'product_type': 'Food',
#   'country': 'United States',
#   'product_description': 'Pistachios, Shelled Raw, 4 /2.5 Packed by Tropical Food Nut & Fruit- Orlando, FL 32811',
#   'code_info': 'GFS Item #866580  10015196182512, Lot 060412,  052912, Best By  02/03/13',
#   'address_1': '333 50th St Sw',
#   'address_2': '',
#   'product_quantity': '7 cases by GFS distribution center'},
#  {'classification': 'Class II',
#   'center_classification_date': '20120928',
#   'report_date': '20121010',
#   'postal_code': '17529-9769',
#   'termination_date': '20131018',
#   'recall_initiation_date': '20120828',
#   'recall_number': 'F-2447-2012',
#   'city': 'Gordonville',
#   'event_id': '63055',
#   'distribution_pattern': 'Distribution within the US to PA.',
#   'openfda': {},
#   'recalling_firm': "Sadie's Salads",
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'state': 'PA',
#   'reason_for_recall': 'Product labeling fails to declare allergens (wheat and milk) contained in the macaroni and cheese used as sub-ingredients',
#   'initial_firm_notification': 'Telephone',
#   'status': 'Terminated',
#   'product_type': 'Food',
#   'country': 'United States',
#   'product_description': "Sadie's Salads Macaroni and Cheese, 5 lb and 10 lb plastic tubs",
#   'code_info': 'All product with use by date up to and including September 13, 2012',
#   'address_1': '4021B Old Philadelphia Pike',
#   'address_2': '',
#   'product_quantity': 'Unknown'},
#  {'classification': 'Class I',
#   'center_classification_date': '20121001',
#   'report_date': '20121010',
#   'postal_code': '53511-9554',
#   'termination_date': '20121220',
#   'recall_initiation_date': '20120831',
#   'recall_number': 'F-0007-2013',
#   'city': 'Beloit',
#   'event_id': '63084',
#   'distribution_pattern': 'The product was distributed to UT.',
#   'openfda': {},
#   'recalling_firm': 'Kerry Foods',
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'state': 'WI',
#   'reason_for_recall': 'The product may be contaminated with Salmonella.',
#   'initial_firm_notification': 'Telephone',
#   'status': 'Terminated',
#   'product_type': 'Food',
#   'country': 'United States',
#   'product_description': 'Kerry Organic Pure 900, Organic Soy Protein Isolate, Item #722234.454, packaged in 20-kg. bags.  The firm name on the label is Kerry China, Shanghai, China.',
#   'code_info': 'Lot #O4120710',
#   'address_1': '3400 Millington RD',
#   'address_2': 'Beloit, WI 53511 USA',
#   'product_quantity': '118/20-kg. bags'},
#  {'classification': 'Class I',
#   'center_classification_date': '20120928',
#   'report_date': '20121010',
#   'postal_code': '17529-9769',
#   'termination_date': '20131018',
#   'recall_initiation_date': '20120828',
#   'recall_number': 'F-1074-2012',
#   'city': 'Gordonville',
#   'event_id': '63055',
#   'distribution_pattern': 'Distribution within the US to PA.',
#   'openfda': {},
#   'recalling_firm': "Sadie's Salads",
#   'voluntary_mandated': 'Voluntary: Firm Initiated',
#   'state': 'PA',
#   'reason_for_recall': 'Product labeling fails to declare allergens (egg, soybean oil) contained in mayonnaise used as ingredients',
#   'initial_firm_notification': 'Telephone',
#   'status': 'Terminated',
#   'product_type': 'Food',
#   'country': 'United States',
#   'product_description': "Sadie's Salads Cole Slaw, 5 lb, 10 lb and 30 lb plastic tubs",
#   'code_info': 'All product with use by date up to and including September 13, 2012',
#   'address_1': '4021B Old Philadelphia Pike',
#   'address_2': '',
#   'product_quantity': 'Unknown'}]
